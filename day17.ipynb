# %%
import numpy as np 
n=np.array([15, -3, 22, -1, 18, 0, -5, 30])
n[n<0]=0
n
# Out:
# array([15,  0, 22,  0, 18,  0,  0, 30])

# %%
score= np.array([50,75,80,90,60])
curved_score=(score/score.max())*100
curved_score
# Out:
# array([ 55.55555556,  83.33333333,  88.88888889, 100.        ,
#         66.66666667])

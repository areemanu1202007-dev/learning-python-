# %% [markdown]
# *#STARTING NUMPY*

# %%
import numpy as np
myarr=np.array([[3,6,32,7]])
myarr
myarr[0]
myarr[0,0]
#lets change the value of 6 
myarr[0,1]=12
myarr
# Out:
# array([[ 3, 12, 32,  7]])

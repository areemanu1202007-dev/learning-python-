# %%
a = input("enter the string :")
b = a.count('a')
print("the number of times 'a' appears in the string is :", b, "and the string is :", a)
# Out:
# the number of times 'a' appears in the string is : 2 and the string is : Manushka

# %%
a = input("enter the string :")
b = len(a)
print("the length of the string is :", b, "and the string is :", a)
# Out:
# the length of the string is : 8 and the string is : Manushka
